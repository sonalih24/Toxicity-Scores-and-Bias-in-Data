# %%
# Import the necessary modules
import matplotlib.pyplot as plt
import pandas as pd
import time
# import numpy as np

# %%
df = pd.read_csv('C:\\Users\\sonal\\OneDrive\\Desktop\\Education\\06 Spring 2022\\Comp Sci\\Homework\\labeled_and_scored_comments.csv')

# %%
df.sort_values(['score'])
# Out:
#                      id                                       comment_text  \
# 1158   61a85266de70cca0                         Можешь говорить по русски.
# 5246   030a9ba0b32b4456  Rodzina Krusenstern Potomkowie Admirała Adama ...
# 11040  a6814193ac6b4705  The opening paragraph states that the game is ...
# 24192  f0d6dee96e057a5b  The book is used as a source in a number of ar...
# 2332   cbb9268d3c7429c1     Vals Vienés \n |Rumba \n |Cha Cha Chá(ciclo 7)
# ...                 ...                                                ...
# 19994  1429a2c930688317                          you fucking piece of shit
# 28728  d82e45eb103ad07b                   fuck off you stupid aspy asshole
# 25535  e9b92c6c6b01aeef  FUCK YOU YOU PIECE OF SHIT \n FUCK YOU YOU PIE...
# 25945  e783fd267f3a9d3b  FUCK WIKIPEDIA ON WHEELS! \n\nFuck off wikiped...
# 17833  364b6c24210e2345  Fuck you you fucking pig!\n\nYou motherfucking...
#
# ...

# %%
plt.hist(df['score'])
plt.show()

# %%
sub_df = df.loc[df['toxic']==1]

# %%
sub_df
# Out:
#                      id                                       comment_text  \
# 8      00091c35fa9d0465  == Arabs are committing genocide in Iraq, but ...
# 24     0013fed3aeae76b7  DJ Robinson is gay as hell! he sucks his dick ...
# 29     0017d4d47894af05               :Fuck off, you anti-semitic cunt.  |
# 37     001d739c97bc2ae4  How dare you vandalize that page about the HMS...
# 38     001eff4007dbb65b  ::No, he is an arrogant, self serving, immatur...
# ...                 ...                                                ...
# 41297  94a6beeb87ab68c0               Damn, those are some rancid sources.
# 41299  94a5024323152cd1  ==Why does it bother you, fuckface?89.123.100....
# 41325  948cb4052152869b  WHAT?  That's past stuff.  Stop being an insti...
# 41332  9481cd7393b583c9  RE: \n\nIt's a fucking album cover, how the fu...
# 41333  9480bff99f91a69e  Lesbian Teenager \nHow about the fact she was ...
#
# ...

# %%
df[df['toxic']==1].sort_values(['score'])
# Out:
#                      id                                       comment_text  \
# 34556  b8faa0ed6f557ad9  And we have a winner for the douchiest comment...
# 30103  d0bae6a8c78773bf  Look, what's your problem, kid? Have you got s...
# 15367  5f04a07ebb59fa3d  Alansohn tucks his sack back every now and the...
# 19650  1942efd2dad5e9c5             You need to end this now, cold turkey.
# 38493  a39b4836714430a1  SMOKE WEED ERRYDAY RIGHT BEFORE CLASS....PROFE...
# ...                 ...                                                ...
# 19994  1429a2c930688317                          you fucking piece of shit
# 28728  d82e45eb103ad07b                   fuck off you stupid aspy asshole
# 25535  e9b92c6c6b01aeef  FUCK YOU YOU PIECE OF SHIT \n FUCK YOU YOU PIE...
# 25945  e783fd267f3a9d3b  FUCK WIKIPEDIA ON WHEELS! \n\nFuck off wikiped...
# 17833  364b6c24210e2345  Fuck you you fucking pig!\n\nYou motherfucking...
#
# ...

# %%
df[df['identity_hate']==1].sort_values(['score'])
# Out:
#                      id                                       comment_text  \
# 31352  ca322730a9b08795  Mmmm... yes... a pint of palestinian blood wou...
# 15076  63c44599fce8f0c2  Basically, homosexuality lowers productivity, ...
# 11524  9dd29a3d27d96473  Fighting freedom-hating wikiterrorist/admins i...
# 23915  f24a0fcc1f403334  yeah after few days some jews will say nasser ...
# 40496  9903cd41f8b37abb              REDIRECT Talk:Bolivian chinchilla rat
# ...                 ...                                                ...
# 25351  eac84ebd5a2b6393  FUCK U DIRTY INDIAN \n\nI HATE INDIANS...YOU G...
# 7304   e297dd3d3e70c9e9                      Fuck u bitch \n\nFuck u Bitch
# 16436  4ebb0ac23020ce07               your gay \n\nyou're a fucking faggot
# 21407  ff3c218c3be4d2d4                    fucking germanian piece of shit
# 27863  dcfe7014ec173fa8                     Fuck you Indian piece of shit.
#
# ...

# %%
sub_df = df[(df['toxic']==1) & (df['identity_hate']==1)]

# %%
sub_df
# Out:
#                      id                                       comment_text  \
# 24     0013fed3aeae76b7  DJ Robinson is gay as hell! he sucks his dick ...
# 62     03c6344729c4e665  Azerbaijanis Proud of Ramil Safarov  \n If I h...
# 123    07e0fe7770ca2abe  Bill \n\n  \n\n  \n\n  \n dear \n sir \n\n  \n...
# 143    0bc799a58279849f                         I knew he was a dirty jew.
# 210    0f98c8a6a7fa84d3  vandels are makin your vag extra wide. please ...
# ...                 ...                                                ...
# 40867  96f64bff8d04acd8  YOU BRAINLESS EDITORS \n\nYou idots are probab...
# 40936  969b55cf705cb672  HOW MANY PALESTINIAN CHILDREN HAVE YOU SLAUGHT...
# 41017  9622c82f97eb26cd  She is a Motherfucker \n\nI will block you Mot...
# 41062  95ddf8be1b12c559  In defence of China! \n\nHey Koreans, who the ...
# 41238  94f8302c2e339bae  THIS IS AWFUL, JUST AWFUL!!! ALL GERMANS ARE M...
#
# ...

# %%
from googleapiclient.discovery import build
import json

def get_toxicity_score(comment):
    API_KEY = ''
    
    client = build("commentanalyzer", "v1alpha", developerKey=API_KEY, discoveryServiceUrl = "https://commentanalyzer.googleapis.com/$discovery/rest?version=v1alpha1", static_discovery = False,)
    analyze_request = {'comment': { 'text': comment}, 'requestedAttributes': {'TOXICITY': {}}}
    response = client.comments().analyze(body=analyze_request).execute()
    toxicity_score = response["attributeScores"]["TOXICITY"]["summaryScore"]["value"]

    return toxicity_score

# %%
comment_list = ['lesbian', 'gay', 'bisexual', 'transgender', 'queer']

for comment in comment_list:
    score = get_toxicity_score(comment)
    print(comment, score)
    time.sleep(1)
# Out:
# lesbian 0.60887975
# gay 0.77029157
# bisexual 0.48960546
# transgender 0.37589672
# queer 0.4830629

# %%
comment_list = ['he is gay', 'he is bisexual', 'he is transgender', 'he is queer']

for comment in comment_list:
    score = get_toxicity_score(comment)
    print(comment, score)
    time.sleep(1)
# Out:
# he is gay 0.7963668
# he is bisexual 0.531272
# he is transgender 0.44196212
# he is queer 0.73106015

# %%
comment_list = ['she is lesbian', 'she is gay', 'she is bisexual', 'she is transgender', 'she is queer']

for comment in comment_list:
    score = get_toxicity_score(comment)
    print(comment, score)
    time.sleep(1)
# Out:
# she is lesbian 0.6495244
# she is gay 0.81575257
# she is bisexual 0.53490317
# she is transgender 0.42939407
# she is queer 0.75593907
